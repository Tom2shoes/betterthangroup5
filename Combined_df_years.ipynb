# %%
import pandas as pd
import numpy as np

# %%
# File to Load 
runner_2015 = "Resources/marathon_results_2015.csv"
runner_2016 = "Resources/marathon_results_2016.csv"
runner_2017 = "Resources/marathon_results_2017.csv"

# %%
# File to Read
runner_2015_df = pd.read_csv(runner_2015)
runner_2016_df = pd.read_csv(runner_2016)
runner_2017_df = pd.read_csv(runner_2017)

# %%
# Show all 2015 columns
runner_2015_df.columns
# Out:
# Index(['Unnamed: 0', 'Bib', 'Name', 'Age', 'M/F', 'City', 'State', 'Country',
#        'Citizen', 'Unnamed: 9', '5K', '10K', '15K', '20K', 'Half', '25K',
#        '30K', '35K', '40K', 'Pace', 'Proj Time', 'Official Time', 'Overall',
#        'Gender', 'Division'],
#       dtype='object')

# %%
# Show all 2016 columns
runner_2016_df.columns
# Out:
# Index(['Bib', 'Name', 'Age', 'M/F', 'City', 'State', 'Country', 'Citizen',
#        'Unnamed: 8', '5K', '10K', '15K', '20K', 'Half', '25K', '30K', '35K',
#        '40K', 'Pace', 'Proj Time', 'Official Time', 'Overall', 'Gender',
#        'Division'],
#       dtype='object')

# %%
# Show all 2017 columns
runner_2017_df.columns
# Out:
# Index(['Unnamed: 0', 'Bib', 'Name', 'Age', 'M/F', 'City', 'State', 'Country',
#        'Citizen', 'Unnamed: 9', '5K', '10K', '15K', '20K', 'Half', '25K',
#        '30K', '35K', '40K', 'Pace', 'Proj Time', 'Official Time', 'Overall',
#        'Gender', 'Division'],
#       dtype='object')

# %%
# Display data frame to see what information it contains
runner_2015_df.head()
# Out:
#    Unnamed: 0 Bib                   Name  Age M/F         City State Country  \
# 0           0   3         Desisa, Lelisa   25   M         Ambo   NaN     ETH
# 1           1   4  Tsegay, Yemane Adhane   30   M  Addis Ababa   NaN     ETH
# 2           2   8         Chebet, Wilson   29   M     Marakwet   NaN     KEN
# 3           3  11       Kipyego, Bernard   28   M      Eldoret   NaN     KEN
# 4           4  10          Korir, Wesley   32   M       Kitale   NaN     KEN
#
#   Citizen Unnamed: 9   ...         25K      30K      35K      40K     Pace  \
# 0     NaN        NaN   ...     1:16:07  1:32:00  1:47:59  2:02:39  0:04:56
# 1     NaN        NaN   ...     1:16:07  1:31:59  1:47:59  2:02:42  0:04:58
# 2     NaN        NaN   ...     1:16:07  1:32:00  1:47:59  2:03:01  0:04:59
# 3     NaN        NaN   ...     1:16:07  1:32:00  1:48:03  2:03:47  0:05:00
# 4     NaN        NaN   ...     1:16:07  1:32:00  1:47:59  2:03:27  0:05:00
#
#   Proj Time Official Time Overall Gender Division
# ...

# %%
# Only keep the columns we needed
runner_2015_df = runner_2015_df[["Bib", "Name", "Age", "M/F", "City", "State", "Country", 
                                       "5K", "10K", "15K", "20K", "Half", "25K","30K", "35K", 
                                       "40K", "Pace", "Official Time", "Overall"]]
# Adding Year column
runner_2015_df["Year"] = 2015

# Export csv file
runner_2015_df.to_csv("runner_2015_df.csv")

runner_2015_df.head()
# Out:
#   Bib                   Name  Age M/F         City State Country       5K  \
# 0   3         Desisa, Lelisa   25   M         Ambo   NaN     ETH  0:14:43
# 1   4  Tsegay, Yemane Adhane   30   M  Addis Ababa   NaN     ETH  0:14:43
# 2   8         Chebet, Wilson   29   M     Marakwet   NaN     KEN  0:14:43
# 3  11       Kipyego, Bernard   28   M      Eldoret   NaN     KEN  0:14:43
# 4  10          Korir, Wesley   32   M       Kitale   NaN     KEN  0:14:43
#
#        10K      15K      20K     Half      25K      30K      35K      40K  \
# 0  0:29:43  0:44:57  1:00:29  1:04:02  1:16:07  1:32:00  1:47:59  2:02:39
# 1  0:29:43  0:44:58  1:00:28  1:04:01  1:16:07  1:31:59  1:47:59  2:02:42
# 2  0:29:43  0:44:57  1:00:29  1:04:02  1:16:07  1:32:00  1:47:59  2:03:01
# 3  0:29:44  0:45:01  1:00:29  1:04:02  1:16:07  1:32:00  1:48:03  2:03:47
# 4  0:29:44  0:44:58  1:00:28  1:04:01  1:16:07  1:32:00  1:47:59  2:03:27
#
#       Pace Official Time  Overall  Year
# ...

# %%
# Only keep the columns we needed
runner_2016_df = runner_2016_df[["Bib", "Name", "Age", "M/F", "City", "State", "Country", 
                                       "5K", "10K", "15K", "20K", "Half", "25K","30K", "35K", 
                                       "40K", "Pace", "Official Time", "Overall"]]
# Adding Year column
runner_2016_df["Year"] = 2016

# Export csv file
runner_2016_df.to_csv("runner_2016_df.csv")

runner_2016_df.head()
# Out:
#   Bib                   Name  Age M/F         City State Country       5K  \
# 0   5    Hayle, Lemi Berhanu   21   M  Addis Ababa   NaN     ETH  0:15:47
# 1   1         Desisa, Lelisa   26   M         Ambo   NaN     ETH  0:15:47
# 2   6  Tsegay, Yemane Adhane   31   M  Addis Ababa   NaN     ETH  0:15:46
# 3  11          Korir, Wesley   33   M       Kitale   NaN     KEN  0:15:46
# 4  14       Lonyangata, Paul   23   M      Eldoret   NaN     KEN  0:15:46
#
#        10K      15K      20K     Half      25K      30K      35K      40K  \
# 0  0:31:20  0:47:07  1:03:14  1:06:45  1:19:15  1:34:17  1:50:24  2:05:59
# 1  0:31:21  0:47:08  1:03:14  1:06:46  1:19:15  1:34:17  1:50:24  2:05:59
# 2  0:31:20  0:47:07  1:03:13  1:06:44  1:19:15  1:34:45  1:50:48  2:06:47
# 3  0:31:21  0:47:07  1:03:14  1:06:46  1:19:16  1:34:45  1:50:48  2:06:47
# 4  0:31:21  0:47:08  1:03:14  1:06:46  1:19:18  1:34:46  1:51:30  2:08:11
#
#       Pace Official Time  Overall  Year
# ...

# %%
# Only keep the columns we needed
runner_2017_df = runner_2017_df[["Bib", "Name", "Age", "M/F", "City", "State", "Country", 
                                       "5K", "10K", "15K", "20K", "Half", "25K","30K", "35K", 
                                       "40K", "Pace", "Official Time", "Overall"]]
# Adding Year column
runner_2017_df["Year"] = 2017

# Export csv file
runner_2017_df.to_csv("runner_2017_df.csv")

runner_2017_df.head()
# Out:
#   Bib              Name  Age M/F           City State Country       5K  \
# 0  11   Kirui, Geoffrey   24   M       Keringet   NaN     KEN  0:15:25
# 1  17       Rupp, Galen   30   M       Portland    OR     USA  0:15:24
# 2  23     Osako, Suguru   25   M   Machida-City   NaN     JPN  0:15:25
# 3  21  Biwott, Shadrack   32   M  Mammoth Lakes    CA     USA  0:15:25
# 4   9    Chebet, Wilson   31   M       Marakwet   NaN     KEN  0:15:25
#
#        10K      15K      20K     Half      25K      30K      35K      40K  \
# 0  0:30:28  0:45:44  1:01:15  1:04:35  1:16:59  1:33:01  1:48:19  2:02:53
# 1  0:30:27  0:45:44  1:01:15  1:04:35  1:16:59  1:33:01  1:48:19  2:03:14
# 2  0:30:29  0:45:44  1:01:16  1:04:36  1:17:00  1:33:01  1:48:31  2:03:38
# 3  0:30:29  0:45:44  1:01:19  1:04:45  1:17:00  1:33:01  1:48:58  2:04:35
# 4  0:30:28  0:45:44  1:01:15  1:04:35  1:16:59  1:33:01  1:48:41  2:05:00
#
#       Pace Official Time  Overall  Year
# 0  0:04:57       2:09:37        1  2017
# ...

# %%
# Concatenate all DataFrame together
final_df = pd.concat([runner_2015_df, runner_2016_df, runner_2017_df])

# %%
# Display combined result
final_df
# Out:
#          Bib                      Name  Age M/F               City State  \
# 0          3            Desisa, Lelisa   25   M               Ambo   NaN
# 1          4     Tsegay, Yemane Adhane   30   M        Addis Ababa   NaN
# 2          8            Chebet, Wilson   29   M           Marakwet   NaN
# 3         11          Kipyego, Bernard   28   M            Eldoret   NaN
# 4         10             Korir, Wesley   32   M             Kitale   NaN
# 5          9      Chepkwony, Frankline   30   M           Koibatek   NaN
# 6         14        Ritzenhein, Dathan   32   M           Rockford    MI
# 7          1           Keflezighi, Meb   39   M          San Diego    CA
# 8          5              Tola, Tadese   27   M        Addis Ababa   NaN
# 9         16           Shafar, Vitaliy   33   M              Lutsk   NaN
# 10        22           Tegenkamp, Matt   33   M           Portland    OR
# 11        19        Eggleston, Jeffrey   30   M            Boulder    CO
# ...

# %%
# Export final file to csv
final_df.to_csv("Year_Combined.csv")
